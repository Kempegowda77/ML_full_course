# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Create DataFrame
data = {
    "Education": ["High School", "Bachelor", "Master", "PhD", "Bachelor", "Master"],
    "Income": ["Low", "Medium", "High", "High", "Low", "Medium"],
    "Purchase": ["No", "Yes", "Yes", "Yes", "No", "Yes"]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Create LabelEncoder
le = LabelEncoder()

# Encode each column
df["Education"] = le.fit_transform(df["Education"])
df["Income"] = le.fit_transform(df["Income"])
df["Purchase"] = le.fit_transform(df["Purchase"])

print("\nEncoded DataFrame:")
print(df)
# Out:
# Original DataFrame:
#      Education  Income Purchase
# 0  High School     Low       No
# 1     Bachelor  Medium      Yes
# 2       Master    High      Yes
# 3          PhD    High      Yes
# 4     Bachelor     Low       No
# 5       Master  Medium      Yes
#
# Encoded DataFrame:
#    Education  Income  Purchase
# 0          1       1         0
# 1          0       2         1
# 2          2       0         1
# 3          3       0         1
# 4          0       1         0
# 5          2       2         1
